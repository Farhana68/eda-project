# %% [markdown]
# Importing necessary libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# Loading the dataset

# %%
# Load the dataset
df = pd.read_csv('Dataset-Mental-Disorders.csv')

# Display the first few rows
df.head()
# Out:
#   Patient Number    Sadness    Euphoric  Exhausted Sleep dissorder Mood Swing  \
# 0     Patiant-01    Usually      Seldom  Sometimes       Sometimes        YES
# 1     Patiant-02    Usually      Seldom    Usually       Sometimes         NO
# 2     Patiant-03  Sometimes  Most-Often  Sometimes       Sometimes        YES
# 3     Patiant-04    Usually      Seldom    Usually      Most-Often        YES
# 4     Patiant-05    Usually     Usually  Sometimes       Sometimes         NO
#
#   Suicidal thoughts Anorxia Authority Respect Try-Explanation  \
# 0              YES       NO                NO             YES
# 1               YES      NO                NO              NO
# 2                NO      NO                NO             YES
# 3               YES     YES                NO             YES
# 4                NO      NO                NO              NO
#
#   Aggressive Response Ignore & Move-On Nervous Break-down Admit Mistakes  \
# ...

# %% [markdown]
# Checking the structure of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Patient Number       120 non-null    object
#  1   Sadness              120 non-null    object
#  2   Euphoric             120 non-null    object
#  3   Exhausted            120 non-null    object
#  4   Sleep dissorder      120 non-null    object
#  5   Mood Swing           120 non-null    object
#  6   Suicidal thoughts    120 non-null    object
#  7   Anorxia              120 non-null    object
#  8   Authority Respect    120 non-null    object
#  9   Try-Explanation      120 non-null    object
#  10  Aggressive Response  120 non-null    object
#  11  Ignore & Move-On     120 non-null    object
#  12  Nervous Break-down   120 non-null    object
#  13  Admit Mistakes       120 non-null    object
#  14  Overthinking         120 non-null    object
# ...

# %%
df.shape
# Out:
# (120, 19)

# %%
df.columns
# Out:
# Index(['Patient Number', 'Sadness', 'Euphoric', 'Exhausted', 'Sleep dissorder',
#        'Mood Swing', 'Suicidal thoughts', 'Anorxia', 'Authority Respect',
#        'Try-Explanation', 'Aggressive Response', 'Ignore & Move-On',
#        'Nervous Break-down', 'Admit Mistakes', 'Overthinking',
#        'Sexual Activity', 'Concentration', 'Optimisim', 'Expert Diagnose'],
#       dtype='object')

# %%
df.sample(10)
# Out:
#     Patient Number     Sadness    Euphoric   Exhausted Sleep dissorder  \
# 36      Patiant-37   Sometimes      Seldom     Usually          Seldom
# 35      Patiant-36  Most-Often      Seldom     Usually       Sometimes
# 103    Patiant-104   Sometimes  Most-Often   Sometimes          Seldom
# 79      Patiant-80  Most-Often      Seldom  Most-Often       Sometimes
# 16      Patiant-17   Sometimes     Usually   Sometimes       Sometimes
# 26      Patiant-27   Sometimes   Sometimes     Usually       Sometimes
# 66      Patiant-67   Sometimes     Usually     Usually         Usually
# 81      Patiant-82  Most-Often   Sometimes   Sometimes         Usually
# 83      Patiant-84      Seldom     Usually  Most-Often      Most-Often
# 118    Patiant-119     Usually   Sometimes      Seldom          Seldom
#
#     Mood Swing Suicidal thoughts Anorxia Authority Respect Try-Explanation  \
# 36         YES               YES     YES                NO             YES
# ...

# %%
df.isnull().sum()
# Out:
# Patient Number         0
# Sadness                0
# Euphoric               0
# Exhausted              0
# Sleep dissorder        0
# Mood Swing             0
# Suicidal thoughts      0
# Anorxia                0
# Authority Respect      0
# Try-Explanation        0
# Aggressive Response    0
# Ignore & Move-On       0
# Nervous Break-down     0
# Admit Mistakes         0
# Overthinking           0
# Sexual Activity        0
# Concentration          0
# Optimisim              0
# Expert Diagnose        0
# dtype: int64

# %%
df = df.drop(columns=["Patient Number"])

# %%
for col in df.columns:
    print(f"Column: {col}")
    print(df[col].unique())
    print("-" * 40)
# Out:
# Column: Sadness
# ['Usually' 'Sometimes' 'Seldom' 'Most-Often']
# ----------------------------------------
# Column: Euphoric
# ['Seldom' 'Most-Often' 'Usually' 'Sometimes']
# ----------------------------------------
# Column: Exhausted
# ['Sometimes' 'Usually' 'Seldom' 'Most-Often']
# ----------------------------------------
# Column: Sleep dissorder
# ['Sometimes' 'Most-Often' 'Usually' 'Seldom']
# ----------------------------------------
# Column: Mood Swing
# ['YES' 'NO']
# ----------------------------------------
# Column: Suicidal thoughts
# ['YES ' 'YES' 'NO']
# ----------------------------------------
# Column: Anorxia
# ['NO' 'YES']
# ----------------------------------------
# Column: Authority Respect
# ['NO' 'YES']
# ----------------------------------------
# Column: Try-Explanation
# ['YES' 'NO']
# ----------------------------------------
# Column: Aggressive Response
# ['NO' 'YES']
# ----------------------------------------
# Column: Ignore & Move-On
# ['NO' 'YES']
# ...

# %%
df_melted = df.melt(var_name="variable", value_name="value")

plt.figure(figsize=(20, 10))

g = sns.FacetGrid(df_melted, col="variable", col_wrap=4, height=4, sharex=False, sharey=False)

g.map(sns.countplot, "value", palette="viridis")

g.set_titles("{col_name}")
g.set_axis_labels("Categories", "Count")
g.set_xticklabels(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# /home/codespace/.local/lib/python3.12/site-packages/seaborn/axisgrid.py:718: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
